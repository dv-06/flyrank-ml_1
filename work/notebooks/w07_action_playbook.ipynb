# %% [markdown]
# # ML-10 — Content Action Playbook
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/dv-06/flyrank-ml_1/blob/main/work/notebooks/w07_action_playbook.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Ranked actions + reason codes
#
# *The queue: what to do first, and why, in words a human trusts.*
#
# The highest priority pages are those with high impressions, low CTR, poor average position, and older content. These pages should be reviewed first because improving them can have a larger impact on traffic.
#
# Reason codes:
# - High impressions
# - Low CTR
# - Poor average position
# - Older content

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# !git clone https://github.com/dv-06/flyrank-ml_1.git
# %cd flyrank-ml_1
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

df["score"] = (
    df["impressions_90d"].rank(pct=True) * 40
    + (1 - df["ctr"].rank(pct=True)) * 30
    + df["avg_position"].rank(pct=True) * 20
    + df["content_age_days"].rank(pct=True) * 10
)

ranked = df.sort_values("score", ascending=False)

print(ranked[
    ["content_id", "score", "impressions_90d", "ctr",
     "avg_position", "content_age_days"]
].head(20))
# Out:
# Cloning into 'flyrank-ml_1'...
# remote: Enumerating objects: 241, done.
# remote: Counting objects: 100% (241/241), done.
# remote: Compressing objects: 100% (195/195), done.
# remote: Total 241 (delta 117), reused 92 (delta 27), pack-reused 0 (from 0)
# Receiving objects: 100% (241/241), 1.97 MiB | 11.72 MiB/s, done.
# Resolving deltas: 100% (117/117), done.
# /content/flyrank-ml_1/flyrank-ml_1/flyrank-ml_1/flyrank-ml_1
#                  content_id      score  impressions_90d  ctr  avg_position  \
# 4458   content_05133844bff4  88.779667            14803  0.0          54.4
# 8710   content_fb4bf6555c79  88.125000            84093  0.0          45.6
# 10136  content_df71843dcd17  86.867667            27334  0.0          76.4
# 11521  content_75175d878762  86.836000            25748  0.0          48.5
# 25456  content_bc18d49d8f6b  85.995167            32491  0.0          36.2
# 18509  content_095661034f9b  85.675500            23513  0.0          39.4
# ...

# %% [markdown]
# ## 2. Intended use and limits
#
# *Who uses this, for what — and where it stops being valid.*
#
# This playbook is intended for content editors who need to decide which webpages should be refreshed first. The recommendations help prioritize pages but should not replace manual review. External factors such as seasonality, news events, or business priorities are not included in the model.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("Use: prioritize pages for human editorial review.")
print("The score is not an automatic publishing decision.")
print("External factors are not included.")
# Out:
# Use: prioritize pages for human editorial review.
# The score is not an automatic publishing decision.
# External factors are not included.

# %% [markdown]
# ## 3. Human review + the no-go list
#
# *What a person must check before acting. What should never be automated.*
#
# Before updating a page, the editor should check whether the content is still accurate, relevant, and aligned with user intent. The model should never automatically publish changes or remove content without human review.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("Human review is required before taking action.")
print("Do not automatically publish, delete, or rewrite content.")
# Out:
# Human review is required before taking action.
# Do not automatically publish, delete, or rewrite content.

# %% [markdown]
# ## 4. Monitoring / retrain triggers
#
# *What would tell you the recommendations went stale?*
#
# The model should be reviewed when search performance changes significantly, new data becomes available, or the prediction accuracy decreases. Retraining should also be considered after major search engine updates or large content changes.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
triggers = [
    "New training data",
    "Performance changes",
    "Model accuracy decreases",
    "Major search-engine changes"
]

print("Review or retrain when:")
for x in triggers:
    print("-", x)
# Out:
# Review or retrain when:
# - New training data
# - Performance changes
# - Model accuracy decreases
# - Major search-engine changes

# %% [markdown]
# ## 5. Exports for the paper
#
# *Write the queue (and any figures you want to reuse) to work/outputs/ — your paper builds on these files.*
#
# The ranked queue, evaluation results, and feature importance can be exported and reused in the final research paper. These outputs provide evidence for the model's recommendations and support the conclusions of the project.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import os

os.makedirs("work/outputs", exist_ok=True)

ranked.head(100).to_csv(
    "work/outputs/action_playbook_queue.csv",
    index=False
)

print("Queue exported successfully.")
# Out:
# Queue exported successfully.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
