# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/dv-06/flyrank-ml_1/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
# I chose the Content Refresh Prioritization lane because it focuses on helping editors identify pages that may need updating. The starter dataset already contains information about search performance, engagement, and content age, which makes it a good fit for this problem. Instead of checking thousands of pages manually, a ranked list can help editors focus on the pages that are more likely to benefit from a refresh.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# Unit of analysis: Individual webpage
#
# Decision: Whether the webpage should be recommended for content refresh.
#
# Action: Editors review the page and update it if needed.
#
# Cost of a wrong decision: If a page is recommended when it doesn't need updating, time is wasted. If a page that needs a refresh is missed, it may continue to lose traffic and engagement.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*
#
# The dataset contains 30,000 webpages, and 16,262 of them are labeled as declining (54.2%). This shows that many pages may need attention, so prioritizing which pages to refresh first can help editors save time and focus on the most important pages.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

df["is_declining_label"] = (df["trend_direction"].str.lower() == "down").astype(int)

print(f"Total pages: {len(df):,}")
print(f"Declining pages: {df['is_declining_label'].sum():,}")
print(f"Declining rate: {df['is_declining_label'].mean():.1%}")
# Out:
# Total pages: 30,000
# Declining pages: 16,262
# Declining rate: 54.2%

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# This project will identify patterns in the available data and recommend pages that may need a content refresh. The recommendations are meant to help editors decide which pages to review first. The results are based on observations from this dataset and do not prove why pages decline or explain how search engines rank webpages.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
