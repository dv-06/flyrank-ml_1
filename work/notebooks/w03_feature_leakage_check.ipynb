# %% [markdown]
# # ML-05 — Feature Vector and Leakage/Privacy Check
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/dv-06/flyrank-ml_1/blob/main/work/notebooks/w03_feature_leakage_check.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Build the feature vector
#
# *Code that actually builds it — engineered features, categorical handling, fills.*
#
# I will use search performance, engagement, and content-related features to build the feature vector. Missing values will be handled before training, and only information available before making a prediction will be used.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

features = [
    "impressions_90d",
    "clicks_90d",
    "ctr",
    "avg_position",
    "content_age_days",
    "word_count",
    "scroll_rate"
]

X = df[features].fillna(0)

print(X.head())
# Out:
#    impressions_90d  clicks_90d   ctr  avg_position  content_age_days  \
# 0             3803          29  0.76          10.6               187
# 1            15320           7  0.05          20.3               445
# 2            12581          11  0.09          36.5               141
# 3            11751          58  0.49           6.2               463
# 4            19140          24  0.13          44.0               263
#
#    word_count  scroll_rate
# 0      3221.0         4.55
# 1      2481.0        10.00
# 2      3515.0        28.57
# 3         0.0         3.45
# 4      2803.0        24.29

# %% [markdown]
# ## 2. Feature notes (meaning, missing, categorical, available-when?)
#
# *For each feature: what it means, how missing values are handled, and whether it exists BEFORE the moment you predict.*
#
# The selected features describe search visibility, engagement, and content characteristics. Missing values are replaced before training. All of these features are available before making a prediction, so they can be safely used by the model.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. The leakage hunt
#
# *Attack your own features: label-derived columns, future windows, product flags. Show the test.*
#
# I checked the selected features to make sure they do not directly contain the answer I am trying to predict. I excluded fields that are created after the outcome or are derived from the label to avoid data leakage.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

excluded = ["trend_pct"]

for col in excluded:
    print(col, "present:", col in df.columns)
# Out:
# trend_pct present: True

# %% [markdown]
# ## 4. What I excluded and why
#
# *The list of fields you refused to use — with one line of why each.*
#
# I excluded trend_pct because it is directly related to the page's trend and could leak the answer to the model. I also avoided any fields that are generated after the outcome or contain editorial decisions, because they would not be available when making a real prediction.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
